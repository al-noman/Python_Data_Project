# %%
import ast
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])
df["job_skills"] = df.job_skills.apply(lambda skills: ast.literal_eval(skills) if pd.notna(skills) else skills)
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df_US_DA = df[(df["job_country"] == "United States") & (df["job_title_short"] == "Data Analyst")].copy()
df_US_DA
# Out:
#        job_title_short                                     job_title  \
# 36        Data Analyst                                  Data Analyst
# 68        Data Analyst                     Sr. Research Data Analyst
# 73        Data Analyst   Entry level / Systems Data Analyst (Remote)
# 79        Data Analyst                    Data Analyst/Report Writer
# 93        Data Analyst  IT Finance / TBM Data Analyst - Remote | WFH
# ...                ...                                           ...
# 785603    Data Analyst                           Junior Data Analyst
# 785626    Data Analyst                    Data Acquisition Associate
# 785685    Data Analyst                                  Data Analyst
# 785703    Data Analyst       Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst     Expert Business Data Analyst - Now Hiring
#
#             job_location               job_via job_schedule_type  \
# 36        Des Moines, IA       via Trabajo.org         Full-time
# ...

# %%
#min_salary = df_US_DA.salary_year_avg.min()
df_US_DA.salary_year_avg.describe()
# Out:
# count      4350.000000
# mean      94553.964924
# std       33248.650655
# min       25000.000000
# 25%       71262.500000
# 50%       90000.000000
# 75%      112500.000000
# max      375000.000000
# Name: salary_year_avg, dtype: float64

# %%
df_US_DA.salary_year_avg.plot(kind="hist", bins=30, edgecolor="black", xlim=(0, 250_000))
plt.title("Distribution of US Data Analyst Yearly Salaries")
plt.ylabel("Number of jobs")
plt.xlabel("Yearly Salary")

ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f"{int(x/1000)}K"))

# %%
df_ds_hourly = df[(df["job_title_short"] == "Data Scientist") & (df.salary_hour_avg.notna())].copy()
df_ds_hourly
# Out:
#        job_title_short                                          job_title  \
# 448     Data Scientist  Jnr Data Scientist for exciting projects with ...
# 734     Data Scientist  Data Scientist - NLP, regex, OpenCV, Python, A...
# 881     Data Scientist  Data Scientist with expertise in deep learning...
# 1100    Data Scientist                         Data Scientist - R, Python
# 1382    Data Scientist                                     Data Scientist
# ...                ...                                                ...
# 783522  Data Scientist                                     Data Scientist
# 783753  Data Scientist           Data Scientist 3 - Full-time / Part-time
# 783976  Data Scientist                  Data Scientist - Contract to Hire
# 785476  Data Scientist                               Data Scientist, Lead
# 785492  Data Scientist                                     Data Scientist
#
#            job_location       job_via         job_schedule_type  \
# ...

# %%
df_ds_hourly.salary_hour_avg.plot(
  kind="hist", 
  bins=40, 
  edgecolor="black", 
  xlim=(0, 150), 
  xlabel="Hourly salary in USD($)", 
  ylabel="Number of job post", 
  title="Data Scientist Hourly Salaries"
)
plt.show()

# %%
df_skills = df.copy()

# %%
df_skills = df_skills.dropna(subset=["job_skills"])
df_skills
# Out:
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_skills["skill_count"] = df_skills.job_skills.apply(lambda skills: skills.__len__())
df_skills
# Out:
# /tmp/ipykernel_516819/2147746637.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_skills["skill_count"] = df_skills.job_skills.apply(lambda skills: skills.__len__())
#           job_title_short                                          job_title  \
# 1            Data Analyst                                       Data Analyst
# 2           Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3           Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4           Data Engineer                             Data Engineer- Sr Jobs
# 5           Data Engineer                                  GCP Data Engineer
# ...                   ...                                                ...
# ...

# %%
df_skills = df_skills.drop(columns=["num_of_skills"])
df_skills.head()
# Out:
#   job_title_short                                          job_title  \
# 1    Data Analyst                                       Data Analyst
# 2   Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3   Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4   Data Engineer                             Data Engineer- Sr Jobs
# 5   Data Engineer                                  GCP Data Engineer
#
#                    job_location             job_via         job_schedule_type  \
# 1  Guadalajara, Jalisco, Mexico    via BeBee México                 Full-time
# 2               Berlin, Germany        via LinkedIn                 Full-time
# 3               San Antonio, TX   via Diversity.com                 Full-time
# 4                Washington, DC  via Clearance Jobs                 Full-time
# 5                      Anywhere    via ZipRecruiter  Contractor and Temp work
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
df_skills.skill_count.plot(
  kind="hist", 
  bins=50, 
  edgecolor="black",
  xlim=(0,25),
  xlabel="Number of skills required",
  ylabel="Number of job posts",
  title="Job Postings by Number of Skills"
)
plt.show()

# %%
df[df["job_title_short"] == "Data Engineer"].salary_year_avg.plot(
  kind="hist", 
  bins=30, 
  edgecolor="black",
  xlim=(0,400_000),
  xlabel="Salary",
  ylabel="Number of job posts",
  title="Data Engineer Salaries"
)
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda salary, pos: f"${int(salary/1000)}K"))
plt.show()
