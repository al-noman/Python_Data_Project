# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset("lukebarousse/data_jobs")
df = dataset["train"].to_pandas()

df["job_posted_date"] = pd.to_datetime(df["job_posted_date"])
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
# Sample dataset of job postings in January
job_postings_jan = pd.DataFrame({
    'job_id': [1, 2, 3, 4, 5],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company A', 'Company B', 'Company C', 'Company D', 'Company E'],
    'job_posted_date': pd.to_datetime(['2024-01-02', '2024-01-07', '2024-01-14', '2024-01-19', '2024-01-24'])
})

print(job_postings_jan)

job_postings_feb = pd.DataFrame({
    'job_id': [6, 7, 8, 9, 10],
    'job_title': ['Data Scientist', 'Data Analyst', 'Machine Learning Engineer', 'Data Scientist', 'Data Engineer'],
    'company': ['Company F', 'Company G', 'Company H', 'Company I', 'Company J'],
    'job_posted_date': pd.to_datetime(['2024-02-05', '2024-02-09', '2024-02-12', '2024-02-18', '2024-02-22'])
})

job_postings_feb
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24
#    job_id                  job_title    company job_posted_date
# 0       6             Data Scientist  Company F      2024-02-05
# 1       7               Data Analyst  Company G      2024-02-09
# 2       8  Machine Learning Engineer  Company H      2024-02-12
# 3       9             Data Scientist  Company I      2024-02-18
# 4      10              Data Engineer  Company J      2024-02-22

# %%
pd.concat([job_postings_jan, job_postings_feb])
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24
# 0       6             Data Scientist  Company F      2024-02-05
# 1       7               Data Analyst  Company G      2024-02-09
# 2       8  Machine Learning Engineer  Company H      2024-02-12
# 3       9             Data Scientist  Company I      2024-02-18
# 4      10              Data Engineer  Company J      2024-02-22

# %%
combined_job_posts = pd.concat([job_postings_jan, job_postings_feb], ignore_index=True)
combined_job_posts
# Out:
#    job_id                  job_title    company job_posted_date
# 0       1             Data Scientist  Company A      2024-01-02
# 1       2               Data Analyst  Company B      2024-01-07
# 2       3  Machine Learning Engineer  Company C      2024-01-14
# 3       4             Data Scientist  Company D      2024-01-19
# 4       5              Data Engineer  Company E      2024-01-24
# 5       6             Data Scientist  Company F      2024-02-05
# 6       7               Data Analyst  Company G      2024-02-09
# 7       8  Machine Learning Engineer  Company H      2024-02-12
# 8       9             Data Scientist  Company I      2024-02-18
# 9      10              Data Engineer  Company J      2024-02-22

# %%
combined_job_posts.set_index("job_id", inplace=True)
combined_job_posts
# Out:
#                         job_title    company job_posted_date
# job_id
# 1                  Data Scientist  Company A      2024-01-02
# 2                    Data Analyst  Company B      2024-01-07
# 3       Machine Learning Engineer  Company C      2024-01-14
# 4                  Data Scientist  Company D      2024-01-19
# 5                   Data Engineer  Company E      2024-01-24
# 6                  Data Scientist  Company F      2024-02-05
# 7                    Data Analyst  Company G      2024-02-09
# 8       Machine Learning Engineer  Company H      2024-02-12
# 9                  Data Scientist  Company I      2024-02-18
# 10                  Data Engineer  Company J      2024-02-22

# %%
df["job_posted_month"] = df["job_posted_date"].dt.strftime("%b")
df
# Out:
#              job_title_short  \
# 0       Senior Data Engineer
# 1               Data Analyst
# 2              Data Engineer
# 3              Data Engineer
# 4              Data Engineer
# ...                      ...
# 785736     Software Engineer
# 785737          Data Analyst
# 785738      Business Analyst
# 785739         Data Engineer
# 785740     Software Engineer
#
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 1                                            Data Analyst
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# ...                                                   ...
# 785736                                    DevOps Engineer
# 785737                                   CRM Data Analyst
# 785738                     Commercial Analyst - Start Now
# ...

# %%
df["job_posted_month"] = df.job_posted_date.dt.strftime("%b")
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %%
all_months = df["job_posted_month"].unique()

df_by_months = { month: df[df["job_posted_month"] == month] for month in all_months}
df_by_months
# Out:
# {'Jun':                   job_title_short  \
#  0            Senior Data Engineer
#  8                Business Analyst
#  16                  Data Engineer
#  17                 Data Scientist
#  24                 Data Scientist
#  ...                           ...
#  785347             Data Scientist
#  785571               Data Analyst
#  785617               Data Analyst
#  785669  Machine Learning Engineer
#  785675               Data Analyst
#
#                                                  job_title  \
#  0       Senior Clinical Data Engineer / Principal Clin...
#  8                Technology & Operations Business Analyst
#  16                                      Big Data Engineer
#  17                                 Data Science Team Lead
#  24                          Data Scientist (DataLab Team)
#  ...                                                   ...
#  785347                    Practicante Científico de Datos
# ...

# %%
df_by_months["Jan"]
# Out:
#           job_title_short                                  job_title  \
# 1            Data Analyst                               Data Analyst
# 20         Data Scientist                             Data Scientist
# 39          Data Engineer                              Data Engineer
# 53          Data Engineer                              Data Engineer
# 55         Data Scientist                             Data Scientist
# ...                   ...                                        ...
# 785699  Software Engineer                        Simulation Engineer
# 785700      Data Engineer                       Data Engineer Ssr/Sr
# 785703       Data Analyst    Data Analyst - CRYPTOGRAPHY - Full-time
# 785704   Business Analyst                           Business Analyst
# 785705       Data Analyst  Expert Business Data Analyst - Now Hiring
#
#                                  job_location             job_via  \
# 1                Guadalajara, Jalisco, Mexico    via BeBee México
# ...

# %%
df_q1 = pd.concat([df_by_months["Jan"], df_by_months["Feb"], df_by_months["Mar"]], ignore_index=True)
df_q1
# Out:
#           job_title_short                                          job_title  \
# 0            Data Analyst                                       Data Analyst
# 1          Data Scientist                                     Data Scientist
# 2           Data Engineer                                      Data Engineer
# 3           Data Engineer                                      Data Engineer
# 4          Data Scientist                                     Data Scientist
# ...                   ...                                                ...
# 220479  Software Engineer                                    DevOps Engineer
# 220480       Data Analyst                                   CRM Data Analyst
# 220481   Business Analyst                     Commercial Analyst - Start Now
# 220482      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 220483  Software Engineer                                 AWS System Analyst
#
# ...

# %%
df_q1.plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 df_q1.plot(kind="bar")
#
# File /opt/anaconda3/envs/python_data_project/lib/python3.11/site-packages/pandas/plotting/_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File /opt/anaconda3/envs/python_data_project/lib/python3.11/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df_q1["job_posted_month"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
unique_job_titles = df.job_title_short.value_counts().index
unique_job_titles
# Out:
# Index(['Data Analyst', 'Data Engineer', 'Data Scientist', 'Business Analyst',
#        'Software Engineer', 'Senior Data Engineer', 'Senior Data Scientist',
#        'Senior Data Analyst', 'Machine Learning Engineer', 'Cloud Engineer'],
#       dtype='object', name='job_title_short')

# %%
df_jobs_by_titles_map = {
  job_title: df[df["job_title_short"] == job_title] for job_title in unique_job_titles
}
df_jobs_by_titles_map["Data Analyst"]
# Out:
#        job_title_short                                          job_title  \
# 1         Data Analyst                                       Data Analyst
# 12        Data Analyst        Stagiaire Data Analyst (H/F) - Lyon (69006)
# 18        Data Analyst                                       Data Analyst
# 31        Data Analyst                           Stage - Data Analyst F/H
# 34        Data Analyst  Data Analyst als Marketing Manager Automation ...
# ...                ...                                                ...
# 785703    Data Analyst            Data Analyst - CRYPTOGRAPHY - Full-time
# 785705    Data Analyst          Expert Business Data Analyst - Now Hiring
# 785715    Data Analyst  Amul Careers 2023 - Apply Online - Data Analys...
# 785717    Data Analyst                 Data & Analytics Architect (w/m/x)
# 785737    Data Analyst                                   CRM Data Analyst
#
#                         job_location  \
# 1       Guadalajara, Jalisco, Mexico
# ...

# %%
df_jobs_by_titles_map["Cloud Engineer"]
# Out:
#        job_title_short                                          job_title  \
# 48      Cloud Engineer                                   Lead Qa Engineer
# 288     Cloud Engineer                      Engineer – Data Center, Cloud
# 295     Cloud Engineer                            Lead Engineer, Building
# 354     Cloud Engineer                                    Server Engineer
# 355     Cloud Engineer                               Environment Engineer
# ...                ...                                                ...
# 785629  Cloud Engineer                           Employee Service Analyst
# 785664  Cloud Engineer                               Performance Engineer
# 785672  Cloud Engineer            Customer Engineer, Apigee, Google Cloud
# 785677  Cloud Engineer                             Engineer 3, Facilities
# 785713  Cloud Engineer  Data Center Chief Engineer, AWS Infrastructure...
#
#                                           job_location  \
# ...

# %%
df_ML_CE = pd.concat([df_jobs_by_titles_map['Machine Learning Engineer'], df_jobs_by_titles_map['Cloud Engineer']], ignore_index=True)
df_ML_CE
# Out:
#                  job_title_short  \
# 0      Machine Learning Engineer
# 1      Machine Learning Engineer
# 2      Machine Learning Engineer
# 3      Machine Learning Engineer
# 4      Machine Learning Engineer
# ...                          ...
# 26406             Cloud Engineer
# 26407             Cloud Engineer
# 26408             Cloud Engineer
# 26409             Cloud Engineer
# 26410             Cloud Engineer
#
#                                                job_title  \
# 0        PhD position in computer science (NLP, finance)
# 1               Sr ML Engineer - Research & NLP (Remote)
# 2      Machine Learning Engineer/Scientist High Perfo...
# 3      Lead Data Scientist/ Lead Machine Learning Eng...
# 4                              Machine Learning Engineer
# ...                                                  ...
# 26406                           Employee Service Analyst
# 26407                               Performance Engineer
# ...

# %%
df_ML_CE.head()
# Out:
#              job_title_short  \
# 0  Machine Learning Engineer
# 1  Machine Learning Engineer
# 2  Machine Learning Engineer
# 3  Machine Learning Engineer
# 4  Machine Learning Engineer
#
#                                            job_title           job_location  \
# 0    PhD position in computer science (NLP, finance)                 Russia
# 1           Sr ML Engineer - Research & NLP (Remote)    Toronto, ON, Canada
# 2  Machine Learning Engineer/Scientist High Perfo...               Anywhere
# 3  Lead Data Scientist/ Lead Machine Learning Eng...  Vancouver, BC, Canada
# 4                          Machine Learning Engineer         Abuja, Nigeria
#
#                    job_via job_schedule_type  job_work_from_home  \
# 0                via hh.ru         Full-time               False
# 1  via Careers At BenchSci         Full-time               False
# 2             via LinkedIn         Full-time                True
# ...

# %%
df.job_schedule_type.value_counts()
# Out:
# job_schedule_type
# Full-time                                701727
# Contractor                                34793
# Internship                                 8742
# Part-time                                  7881
# Full-time and Part-time                    6287
# Full-time and Temp work                    2603
# Full-time and Internship                   2340
# Full-time and Contractor                   2292
# Contractor and Temp work                   2283
# Temp work                                  2169
# Full-time, Part-time, and Internship        264
# Part-time and Internship                    255
# Temp work and Internship                    211
# Full-time, Contractor, and Temp work        194
# Full-time, Temp work, and Internship        173
# Part-time and Contractor                    160
# Full-time, Part-time, and Temp work         131
# Full-time, Part-time, and Contractor        119
# Part-time and Temp work                     111
# ...
